# %%
import pandas as pd
import numpy as np
import ast

# %%
# function to safely converts JSON-like string to dictionaries
# ex: "{'name':'rock', 'age': '23'}" ====> {'name':'rock', 'age': 23}
def parse_json_column(df, column_name):
    for col in column_name:
        df[col] = df[col].apply(ast.literal_eval)
    return df


# Function to convert a list of dictionaries to a dictionary
def list_to_dict(lst):
    if isinstance(lst, list) and lst:
        # Check if 'key' exists in the first dictionary to determine the structure
        if 'key' in lst[0]:
            # If each dict has 'key' and 'value', use 'key' as dict key and 'value' as dict value
            return {item['key']: item['value'] for item in lst if 'key' in item and 'value' in item}
        elif 'value' in lst[0]:
            # If only 'value' is present, use index as the key and 'value' as dict value
            return {index: item['value'] for index, item in enumerate(lst) if 'value' in item}
    return {}  # Return an empty dict if input is not a valid list or contains invalid data

# %%
kolkata_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\kolkata_cars.xlsx")
jaipur_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\jaipur_cars.xlsx")
hyderabad_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\hyderabad_cars.xlsx")
delhi_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\delhi_cars.xlsx")
chennai_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\chennai_cars.xlsx")
bangalore_cars=pd.read_excel(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\bangalore_cars.xlsx")

# %%
kolkata_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
jaipur_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
hyderabad_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1478  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1480  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Diesel', 'bt': 'MUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
delhi_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
chennai_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
bangalore_cars
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %% [markdown]
# kolkata_cars

# %%
kolkata_cars.drop('car_links', axis=1,inplace=True)
kolkata_cars.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs'],
#       dtype='object')

# %%
kolkata_cars=parse_json_column(kolkata_cars, kolkata_cars.columns)

# %% [markdown]
# new_car_detail_kl

# %%
new_car_detail_kl=pd.json_normalize(kolkata_cars['new_car_detail'])
new_car_detail_kl
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %% [markdown]
# new_car_overview

# %%
new_car_overview_kl=pd.json_normalize(kolkata_cars['new_car_overview'])
new_car_overview_kl
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jul 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Nov 20...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# ...            ...                                                ...
# 1376  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1377  Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1378  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1379  Car overview  [{'key': 'Registration Year', 'value': '2012',...
# 1380  Car overview  [{'key': 'Registration Year', 'value': '2017',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_kl.drop('bottomData',inplace = True, axis=1)
new_car_overview_kl

# %%
new_car_overview_kl
# Out:
#            heading                                                top
# 0     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jul 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Nov 20...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2014',...
# ...            ...                                                ...
# 1376  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1377  Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1378  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1379  Car overview  [{'key': 'Registration Year', 'value': '2012',...
# 1380  Car overview  [{'key': 'Registration Year', 'value': '2017',...
#
# [1381 rows x 2 columns]

# %%
new_car_overview_kl_top=new_car_overview_kl['top'].apply(list_to_dict)
new_car_overview_kl_top=pd.json_normalize(new_car_overview_kl_top)
new_car_overview_kl_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2014  Third Party insurance    Petrol  5 Seats
# 1             Jul 2017          Comprehensive    Petrol  5 Seats
# 2             Nov 2021          Comprehensive    Petrol  5 Seats
# 3             Feb 2012            Third Party    Petrol  5 Seats
# 4                 2014  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1376              2022  Third Party insurance    Petrol  5 Seats
# 1377              2014  Third Party insurance    Petrol  5 Seats
# 1378              2011  Third Party insurance    Petrol  5 Seats
# 1379              2012  Third Party insurance    Petrol  5 Seats
# 1380              2017  Third Party insurance    Diesel  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       70,000 Kms  WB02   Third Owner             2494 cc    Automatic
# ...

# %% [markdown]
# new_car_specs

# %%
new_car_specs=pd.json_normalize(kolkata_cars['new_car_specs'])
new_car_specs
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '19.16 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.7 kmpl'}, {'k...
# 2     Specifications  [{'key': 'Mileage', 'value': '19.03 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.73 kmpl'}, {'...
# ...              ...                                                ...
# 1376  Specifications  [{'key': 'Mileage', 'value': '25.24 kmpl'}, {'...
# 1377  Specifications  [{'key': 'Mileage', 'value': '22.74 kmpl'}, {'...
# 1378  Specifications  [{'key': 'Mileage', 'value': '11.74 kmpl'}, {'...
# 1379  Specifications  [{'key': 'Mileage', 'value': '18.5 kmpl'}, {'k...
# 1380  Specifications  [{'key': 'Mileage', 'value': '19.72 kmpl'}, {'...
#
#                                                    data commonIcon
# ...

# %%
new_car_specs_top=new_car_specs['top'].apply(list_to_dict)
new_car_specs_top=pd.json_normalize(new_car_specs_top)
new_car_specs_top
# Out:
#          Mileage   Engine          Max Power                 Torque  \
# 0     19.16 kmpl  2494 CC           158.2bhp                  213Nm
# 1      22.7 kmpl   799 CC           53.64bhp                   72Nm
# 2     19.03 kmpl   999 CC           71.01bhp                   96Nm
# 3        17 kmpl  1197 CC  80 PS at 5200 rpm  11.4 kgm at 4,000 rpm
# 4     15.73 kmpl  1968 CC          174.33bhp                  380Nm
# ...          ...      ...                ...                    ...
# 1376  25.24 kmpl   998 CC           65.71bhp                   89Nm
# 1377  22.74 kmpl   796 CC            47.3bhp                   69Nm
# 1378  11.74 kmpl  1796 CC             186bhp                  285Nm
# 1379   18.5 kmpl  1197 CC           85.80bhp                  114Nm
# 1380  19.72 kmpl  1461 CC          108.45bhp                  245Nm
#
#      Wheel Size Seats
# 0            17     5
# 1           NaN     5
# 2           NaN     5
# 3            14     5
# 4            16     5
# ...

# %%
new_car_specs_data=pd.json_normalize(new_car_specs['data'])
new_car_specs_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1376  {'heading': 'Engine and Transmission', 'subHea...
# 1377  {'heading': 'Engine and Transmission', 'subHea...
# 1378  {'heading': 'Engine and Transmission', 'subHea...
# 1379  {'heading': 'Engine and Transmission', 'subHea...
# 1380  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_data_0=pd.json_normalize(new_car_specs_data[0])
new_car_specs_data_0
# Out:
#                       heading subHeading  \
# 0     Engine and Transmission     Engine
# 1     Engine and Transmission     Engine
# 2     Engine and Transmission     Engine
# 3     Engine and Transmission     Engine
# 4     Engine and Transmission     Engine
# ...                       ...        ...
# 1376  Engine and Transmission     Engine
# 1377  Engine and Transmission     Engine
# 1378  Engine and Transmission     Engine
# 1379  Engine and Transmission     Engine
# 1380  Engine and Transmission     Engine
#
#                                                    list
# 0     [{'key': 'Color', 'value': 'White'}, {'key': '...
# 1     [{'key': 'Color', 'value': 'Red'}, {'key': 'En...
# 2     [{'key': 'Color', 'value': 'Blue'}, {'key': 'E...
# 3     [{'key': 'Color', 'value': 'Red'}, {'key': 'En...
# 4     [{'key': 'Color', 'value': 'White'}, {'key': '...
# ...                                                 ...
# 1376  [{'key': 'Color', 'value': 'Others'}, {'key': ...
# ...

# %%
new_car_specs_data_0_list=new_car_specs_data_0['list'].apply(list_to_dict)
new_car_specs_data_0_list=pd.json_normalize(new_car_specs_data_0_list)
new_car_specs_data_0_list
# Out:
#        Color             Engine Type Displacement          Max Power  \
# 0      White  2AR FXE Petrol Engine          2494   158.2bhp@5700rpm
# 1        Red      0.8L Petrol Engine          799   53.64bhp@5678rpm
# 2       Blue             1.0L energy          999   71.01bhp@6250rpm
# 3        Red          In-Line Engine         1197  80 PS at 5200 rpm
# 4      White       TDI Diesel Engine         1968  174.33bhp@4200rpm
# ...      ...                     ...          ...                ...
# 1376  Others                    K10C          998   65.71bhp@5500rpm
# 1377  Others       F8D Petrol Engine          796    47.3bhp@6000rpm
# 1378  Others  Blue Efficiency Engine         1796     186bhp@5600rpm
# 1379  Others  K Series Petrol Engine         1197   85.80bhp@6000rpm
# 1380  Others   dCi THP Diesel Engine         1461  108.45bhp@4000rpm
#
#                  Max Torque  No of Cylinder  Values per Cylinder  \
# 0             213Nm@4500rpm             4.0                  4.0
# ...

# %%
new_car_specs_data_1=pd.json_normalize(new_car_specs_data[1])
new_car_specs_data_1_list=new_car_specs_data_1['list'].apply(list_to_dict)
new_car_specs_data_1_list=pd.json_normalize(new_car_specs_data_1_list)
new_car_specs_data_1_list
# Out:
#        Length    Width   Height Wheel Base Front Tread Rear Tread Kerb Weight  \
# 0      4825mm   1825mm   1480mm     2775mm      1580mm     1570mm      1625kg
# 1      3429mm   1560mm   1541mm     2348mm         NaN        NaN         770
# 2      3991mm     1750     1605       2500        1536       1535        1055
# 3     3940 mm  1710 mm  1505 mm   2,525 mm    1,505 mm   1,503 mm        1020
# 4      4385mm   2019mm   1608mm     2603mm      1571mm     1575mm      1660kg
# ...       ...      ...      ...        ...         ...        ...         ...
# 1376   3695mm     1655     1555       2435        1430       1440         810
# 1377   3395mm   1490mm   1475mm     2360mm      1295mm     1290mm       720kg
# 1378   4591mm   1770mm   1447mm     2760mm      1549mm     1552mm      1585kg
# 1379   3775mm   1680mm   1620mm     2360mm      1470mm     1480mm      1030kg
# 1380   4315mm   1822mm   1695mm     2673mm      1560mm     1567mm        1350
#
# ...

# %%
new_car_specs_data_2=pd.json_normalize(new_car_specs_data[2])
new_car_specs_data_2_list=new_car_specs_data_2['list'].apply(list_to_dict)
new_car_specs_data_2_list=pd.json_normalize(new_car_specs_data_2_list)
new_car_specs_data_2_list
# Out:
#                Gear Box Drive Type Seating Capacity Steering Type  \
# 0              6 Speed         FWD                5         Power
# 1               5-Speed        2WD                5         Power
# 2               5 Speed        NaN                5      Electric
# 3               5 Speed        FWD                5         Power
# 4     7-Speed S-Tronic         AWD                5         Power
# ...                 ...        ...              ...           ...
# 1376            5-Speed        NaN                5      Electric
# 1377            5 Speed        FWD                5         Power
# 1378            7 Speed        RWD                5         Power
# 1379            5 Speed        FWD                5         Power
# 1380            6 Speed        AWD                5         Power
#
#      Turning Radius Front Brake Type Rear Brake Type         Tyre Type  \
# 0        5.5 metres  Ventilated Disc      Solid Disc   Tubeless,Radial
# ...

# %%
#Combine all the column in csv format
kolkata_cars=pd.concat([new_car_detail_kl,new_car_overview_kl_top,new_car_specs_top,new_car_specs_data_0_list,new_car_specs_data_1_list,new_car_specs_data_2_list],axis=1)

# %%
kolkata_cars
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Steering Type  \
# ...

# %%
kolkata_cars['City']='Kolkata'

# %%
kolkata_cars
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Turning Radius  \
# ...

# %%
# save this csv file
kolkata_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\kolkata_cars.csv",index=False)

# %% [markdown]
# Jaipur cars

# %%
jaipur_cars.drop('car_links',axis=1,inplace=True)

# %%
jaipur_cars.columns
# Out:
# Index(['new_car_detail', 'new_car_overview', 'new_car_feature',
#        'new_car_specs'],
#       dtype='object')

# %%
#parase all
jaipur_cars=parse_json_column(jaipur_cars,jaipur_cars.columns)

# %% [markdown]
# new_car_detail

# %%
new_car_detail_jp=pd.json_normalize(jaipur_cars['new_car_detail'])
new_car_detail_jp
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  centralVariantId  \
# ...

# %% [markdown]
# new_car_overview

# %%
new_car_overview_jp=pd.json_normalize(jaipur_cars['new_car_overview'])
new_car_overview_jp
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jan 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Apr 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# ...            ...                                                ...
# 1115  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1116  Car overview  [{'key': 'Registration Year', 'value': '2007',...
# 1117  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1118  Car overview  [{'key': 'Registration Year', 'value': '2009',...
# 1119  Car overview  [{'key': 'Registration Year', 'value': '2018',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_jp.drop('bottomData',axis=1,inplace=True)

# %%
new_car_overview_jp
# Out:
#            heading                                                top
# 0     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Jan 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Apr 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2016',...
# ...            ...                                                ...
# 1115  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1116  Car overview  [{'key': 'Registration Year', 'value': '2007',...
# 1117  Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1118  Car overview  [{'key': 'Registration Year', 'value': '2009',...
# 1119  Car overview  [{'key': 'Registration Year', 'value': '2018',...
#
# [1120 rows x 2 columns]

# %%
new_car_overview_jp_top=new_car_overview_jp['top'].apply(list_to_dict)
new_car_overview_jp_top=pd.json_normalize(new_car_overview_jp_top)
new_car_overview_jp_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Diesel  5 Seats
# 1             Jan 2012            Third Party    Petrol  5 Seats
# 2                 2016  Third Party insurance    Petrol  5 Seats
# 3             Apr 2017  Third Party insurance    Petrol  5 Seats
# 4                 2016  Third Party insurance    Petrol  5 Seats
# ...                ...                    ...       ...      ...
# 1115              2011  Third Party insurance    Petrol  5 Seats
# 1116              2007  Third Party insurance    Petrol  5 Seats
# 1117              2022  Third Party insurance    Petrol  5 Seats
# 1118              2009  Third Party insurance    Petrol  5 Seats
# 1119              2018  Third Party insurance    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  RJ13  Second Owner             1396 cc       Manual
# ...

# %%
new_car_specs_jp=pd.json_normalize(jaipur_cars['new_car_specs'])
new_car_specs_jp.drop('commonIcon',axis=1,inplace=True)
new_car_specs_jp
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 3     Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '20.51 kmpl'}, {'...
# ...              ...                                                ...
# 1115  Specifications  [{'key': 'Mileage', 'value': '18.6 kmpl'}, {'k...
# 1116  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1117  Specifications  [{'key': 'Mileage', 'value': '19.17 kmpl'}, {'...
# 1118  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1119  Specifications  [{'key': 'Mileage', 'value': '21.4 kmpl'}, {'k...
#
#                                                    data
# ...

# %% [markdown]
# new_car_specs_top

# %%
new_car_specs_jp_top=new_car_specs_jp['top'].apply(list_to_dict)
new_car_specs_jp_top=pd.json_normalize(new_car_specs_jp_top)
new_car_specs_jp_top
# Out:
#          Mileage   Engine Max Power    Torque Wheel Size Seats
# 0     22.54 kmpl  1396 CC  88.73bhp   219.7Nm         16     5
# 1     22.38 kmpl  1197 CC  88.50bhp     113Nm        NaN     5
# 2      23.1 kmpl   998 CC  67.04bhp      90Nm        NaN     5
# 3      18.9 kmpl  1197 CC  81.86bhp  113.75nm        NaN     5
# 4     20.51 kmpl   998 CC     67bhp      90Nm        NaN     5
# ...          ...      ...       ...       ...        ...   ...
# 1115   18.6 kmpl  1199 CC   79.4bhp     108Nm         14     5
# 1116   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1117  19.17 kmpl   999 CC  71.01bhp      96Nm         16     5
# 1118   19.7 kmpl   796 CC   46.3bhp      62Nm         12     5
# 1119   21.4 kmpl  1197 CC   83.1bhp     115Nm        NaN     5
#
# [1120 rows x 6 columns]

# %% [markdown]
# new_car_spec_data

# %%
new_car_specs_jp_data=pd.json_normalize(new_car_specs_jp['data'])
new_car_specs_jp_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1115  {'heading': 'Engine and Transmission', 'subHea...
# 1116  {'heading': 'Engine and Transmission', 'subHea...
# 1117  {'heading': 'Engine and Transmission', 'subHea...
# 1118  {'heading': 'Engine and Transmission', 'subHea...
# 1119  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_jp_data_0=pd.json_normalize(new_car_specs_jp_data[0])
new_car_specs_jp_data_0=new_car_specs_jp_data_0['list'].apply(list_to_dict)
new_car_specs_jp_data_0=pd.json_normalize(new_car_specs_jp_data_0)
new_car_specs_jp_data_0
# Out:
#        Color               Engine Type Displacement         Max Power  \
# 0     Others     U2 CRDI Diesel Engine         1396  88.73bhp@4000rpm
# 1      White         K Series Dual jet         1197  88.50bhp@6000rpm
# 2     Others               K10B Engine          998  67.04bhp@6000rpm
# 3     Silver  Kappa VTVT Petrol Engine         1197  81.86bhp@6000rpm
# 4     Silver        K10B Petrol Engine          998     67bhp@6000rpm
# ...      ...                       ...          ...               ...
# 1115  Others           Smartech Engine         1199   79.4bhp@6200rpm
# 1116  Others            In-Line Engine          796   46.3bhp@6200rpm
# 1117  Others               1.0L energy          999  71.01bhp@6250rpm
# 1118  Others            In-Line Engine          796   46.3bhp@6200rpm
# 1119  Others         VVT Petrol Engine         1197   83.1bhp@6000rpm
#
#                 Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
new_car_specs_jp_data_1=pd.json_normalize(new_car_specs_jp_data[1])
new_car_specs_jp_data_1=new_car_specs_jp_data_1['list'].apply(list_to_dict)
new_car_specs_jp_data_1=pd.json_normalize(new_car_specs_jp_data_1)
new_car_specs_jp_data_1
# Out:
#       Length   Width  Height Wheel Base Front Tread Rear Tread Kerb Weight  \
# 0     3985mm  1734mm  1505mm     2570mm      1505mm     1503mm      1515kg
# 1     3845mm    1735    1530       2450        1530       1530     875-905
# 2     3715mm  1635mm  1565mm     2425mm      1420mm     1410mm       840kg
# 3     3765mm  1660mm  1520mm     2425mm      1479mm     1493mm        1100
# 4     3599mm  1495mm  1700mm     2400mm      1295mm     1290mm       890kg
# ...      ...     ...     ...        ...         ...        ...         ...
# 1115  3640mm  1595mm  1520mm     2375mm         NaN        NaN         990
# 1116  3495mm  1475mm  1460mm     2360mm      1295mm     1290mm       690kg
# 1117  3991mm    1750    1605       2500        1536       1535        1012
# 1118  3495mm  1475mm  1460mm     2360mm      1295mm     1290mm       690kg
# 1119  3995mm  1745mm  1510mm     2520mm      1515mm     1525mm       870kg
#
# ...

# %%
new_car_specs_jp_data_2=pd.json_normalize(new_car_specs_jp_data[2])
new_car_specs_jp_data_2=new_car_specs_jp_data_2['list'].apply(list_to_dict)
new_car_specs_jp_data_2=pd.json_normalize(new_car_specs_jp_data_2)
new_car_specs_jp_data_2
# Out:
#       Gear Box Drive Type Seating Capacity Steering Type Turning Radius  \
# 0      6 Speed        FWD                5         Power     5.2 metres
# 1      5-Speed        NaN                5      Electric            4.8
# 2     5 Speed         FWD                5         Power     4.7 metres
# 3      5 Speed        FWD                5         Power     4.8 metres
# 4      5 Speed        FWD                5         Power     4.6 metres
# ...        ...        ...              ...           ...            ...
# 1115   5 Speed        FWD                5         Power     4.85metres
# 1116   5 Speed        2WD                5        Manual           4.6m
# 1117   5 Speed        NaN                5      Electric            NaN
# 1118   5 Speed        2WD                5        Manual           4.6m
# 1119   5 Speed        FWD                5         Power     4.9 meters
#
#      Front Brake Type Rear Brake Type Top Speed   Acceleration  \
# ...

# %%
jaipur_cars=pd.concat([new_car_detail_jp,new_car_overview_jp_top,new_car_specs_jp_top,new_car_specs_jp_data_0,new_car_specs_jp_data_1,new_car_specs_jp_data_2],axis=1)

# %%
jaipur_cars['City']='Jaipur'

# %%
jaipur_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\jaipur_cars.csv",index=False)
jaipur_cars
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Turning Radius  \
# ...

# %% [markdown]
# Hyderabad_cars

# %%
hyderabad_cars.drop('car_links',axis=1,inplace=True)

# %%
#parase entire table
hyderabad_cars=parse_json_column(hyderabad_cars,hyderabad_cars.columns)

# %%
new_car_details_hd=pd.json_normalize(hyderabad_cars['new_car_detail'])
new_car_details_hd
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback    20,000    Automatic        1  1st Owner
# 1      0  Petrol  Hatchback    85,582       Manual        2  2nd Owner
# 2      0  Petrol        SUV    10,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    50,750       Manual        1  1st Owner
# 4      0  Petrol        SUV    10,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1478   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 1479   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 1480   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 1481   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 1482   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#              oem            model  modelYear  centralVariantId  \
# ...

# %%
new_car_overview_hd=pd.json_normalize(hyderabad_cars['new_car_overview'])
new_car_overview_hd
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2023',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Mar 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# ...            ...                                                ...
# 1478  Car overview  [{'key': 'Registration Year', 'value': '2013',...
# 1479  Car overview  [{'key': 'Registration Year', 'value': '2014',...
# 1480  Car overview  [{'key': 'Registration Year', 'value': '2018',...
# 1481  Car overview  [{'key': 'Registration Year', 'value': '2019',...
# 1482  Car overview  [{'key': 'Registration Year', 'value': '2015',...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_hd.drop('bottomData',axis=1,inplace=True)

# %%
new_car_overview_hd_top=new_car_overview_hd['top'].apply(list_to_dict)
new_car_overview_hd_top=pd.json_normalize(new_car_overview_hd_top)
new_car_overview_hd_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2022  Third Party insurance    Petrol  5 Seats
# 1             Oct 2014  Third Party insurance    Petrol  5 Seats
# 2                 2023  Third Party insurance    Petrol  5 Seats
# 3             Mar 2017  Third Party insurance    Petrol  5 Seats
# 4                 2022  Third Party insurance    Petrol  4 Seats
# ...                ...                    ...       ...      ...
# 1478              2013  Third Party insurance    Diesel  7 Seats
# 1479              2014  Third Party insurance    Diesel  5 Seats
# 1480              2018  Third Party insurance    Diesel  5 Seats
# 1481              2019  Third Party insurance    Diesel  5 Seats
# 1482              2015  Third Party insurance    Diesel  7 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       20,000 Kms  TS04   First Owner              999 cc    Automatic
# ...

# %%
new_car_specs_hd=pd.json_normalize(hyderabad_cars['new_car_specs'])
new_car_specs_hd.drop('commonIcon',axis=1,inplace=True)
new_car_specs_hd
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '16.47 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '21.1 kmpl'}, {'k...
# 2     Specifications  [{'key': 'Engine', 'value': '1197 CC'}, {'key'...
# 3     Specifications  [{'key': 'Mileage', 'value': '21.4 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Engine', 'value': '1997 CC'}, {'key'...
# ...              ...                                                ...
# 1478  Specifications  [{'key': 'Mileage', 'value': '15.1 kmpl'}, {'k...
# 1479  Specifications  [{'key': 'Mileage', 'value': '14.74 kmpl'}, {'...
# 1480  Specifications  [{'key': 'Mileage', 'value': '20.37 kmpl'}, {'...
# 1481  Specifications  [{'key': 'Mileage', 'value': '21.5 kmpl'}, {'k...
# 1482  Specifications  [{'key': 'Mileage', 'value': '12.99 kmpl'}, {'...
#
#                                                    data
# ...

# %%
new_car_specs_hd_top=new_car_specs_hd['top'].apply(list_to_dict)
new_car_specs_hd_top=pd.json_normalize(new_car_specs_hd_top)
new_car_specs_hd_top
# Out:
#          Mileage   Engine  Max Power   Torque Wheel Size Seats
# 0     16.47 kmpl   999 CC  108.62bhp    175nm        R16     5
# 1      21.1 kmpl   814 CC    55.2bhp   74.5Nm        NaN     5
# 2            NaN  1197 CC   81.80bhp  113.8Nm        NaN     5
# 3      21.4 kmpl  1197 CC    83.1bhp    115Nm         16     5
# 4            NaN  1997 CC     150bhp    320Nm         18     4
# ...          ...      ...        ...      ...        ...   ...
# 1478   15.1 kmpl  2179 CC     140bhp    330Nm         17     7
# 1479  14.74 kmpl  2993 CC   270.9bhp    600Nm         20     5
# 1480  20.37 kmpl  1995 CC  187.74bhp    400Nm        R18     5
# 1481   21.5 kmpl  1497 CC   108.5bhp    260Nm        NaN     5
# 1482  12.99 kmpl  2494 CC   100.6bhp    200Nm         15     7
#
# [1483 rows x 6 columns]

# %%
new_car_specs_hd_data=pd.json_normalize(new_car_specs_hd['data'])
new_car_specs_hd_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1478  {'heading': 'Engine and Transmission', 'subHea...
# 1479  {'heading': 'Engine and Transmission', 'subHea...
# 1480  {'heading': 'Engine and Transmission', 'subHea...
# 1481  {'heading': 'Engine and Transmission', 'subHea...
# 1482  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_hd_data_0=pd.json_normalize(new_car_specs_hd_data[0])
new_car_specs_hd_data_0=new_car_specs_hd_data_0['list'].apply(list_to_dict)
new_car_specs_hd_data_0=pd.json_normalize(new_car_specs_hd_data_0)
new_car_specs_hd_data_0
# Out:
#        Color                               Engine Type Displacement  \
# 0     Others                           1.0L TSI Petrol          999
# 1        Red                             Petrol Engine          814
# 2     Others                          1.2 Kappa Petrol         1197
# 3        Red                         VVT Petrol Engine         1197
# 4     Others                 mStallion 150 TGDi Engine         1997
# ...      ...                                       ...          ...
# 1478  Others                       mHawk Diesel Engine         2179
# 1479    Blue                           Diesel S Engine         2993
# 1480    Blue  TwinPower Turbo Inline 4 Cylinder Engine         1995
# 1481  Others        Revotorq, 1.5L Turbocharged engine         1497
# 1482  Others                     2KD-FTV Diesel Engine         2494
#
#                    Max Power          Max Torque  No of Cylinder  \
# 0     108.62bhp@5000-5500rpm  175nm@1750-4000rpm             3.0
# ...

# %%
new_car_specs_hd_data_1=pd.json_normalize(new_car_specs_hd_data[1])
new_car_specs_hd_data_1=new_car_specs_hd_data_1['list'].apply(list_to_dict)
new_car_specs_hd_data_1=pd.json_normalize(new_car_specs_hd_data_1)
new_car_specs_hd_data_1
# Out:
#       Length   Width  Height Wheel Base Front Tread Rear Tread Kerb Weight  \
# 0     3971mm  1682mm  1469mm     2470mm      1457mm     1500mm        1106
# 1     3495mm  1550mm  1500mm     2380mm      1386mm     1368mm         880
# 2     3995mm  1770mm  1617mm     2500mm         NaN        NaN        1106
# 3     3995mm  1745mm  1510mm     2520mm      1505mm     1515mm       890Kg
# 4     3985mm  1855mm  1844mm     2450mm      1520mm     1520mm        1825
# ...      ...     ...     ...        ...         ...        ...         ...
# 1478  4585mm  1890mm  1785mm     2700mm         NaN        NaN        1940
# 1479  4961mm  1877mm  1460mm     2909mm      1559mm     1605mm      1780kg
# 1480  4936mm  2126mm  1466mm     2975mm      1605mm     1630mm        1660
# 1481  3994mm  1811mm  1607mm     2498mm     1540 mm    1530 mm      1305Kg
# 1482  4585mm  1765mm  1760mm     2750mm      1510mm     1510mm      1700kg
#
# ...

# %%
new_car_specs_hd_data_2=pd.json_normalize(new_car_specs_hd_data[2])
new_car_specs_hd_data_2=new_car_specs_hd_data_2['list'].apply(list_to_dict)
new_car_specs_hd_data_2=pd.json_normalize(new_car_specs_hd_data_2)
new_car_specs_hd_data_2
# Out:
#                 Gear Box Drive Type Seating Capacity Steering Type  \
# 0                6 Speed        FWD                5    Electronic
# 1                5 Speed        FWD                5         Power
# 2                5-Speed        NaN                5         Power
# 3                5 Speed        FWD                5         Power
# 4                6 Speed        4X4                4         Power
# ...                  ...        ...              ...           ...
# 1478             6 Speed        FWD                7         Power
# 1479             8 Speed        RWD                5         Power
# 1480  8-Speed Steptronic        RWD                5         Power
# 1481             6 Speed        FWD                5         Power
# 1482             5 Speed        RWD                7         Power
#
#      Turning Radius     Front Brake Type      Rear Brake Type  \
# 0               4.9                 Disc                 Drum
# ...

# %%
hyderabad_cars=pd.concat([new_car_details_hd,new_car_overview_hd_top,new_car_specs_hd_top,new_car_specs_hd_data_0,new_car_specs_hd_data_1,new_car_specs_hd_data_2])

# %%
hyderabad_cars['City']='Hyderabad'

# %%
hyderabad_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\hyderabad_cars.csv",index=False)
hyderabad_cars
# Out:
#        it      ft         bt      km transmission  ownerNo      owner  \
# 0     0.0  Petrol  Hatchback  20,000    Automatic      1.0  1st Owner
# 1     0.0  Petrol  Hatchback  85,582       Manual      2.0  2nd Owner
# 2     0.0  Petrol        SUV  10,000       Manual      1.0  1st Owner
# 3     0.0  Petrol  Hatchback  50,750       Manual      1.0  1st Owner
# 4     0.0  Petrol        SUV  10,000    Automatic      1.0  1st Owner
# ...   ...     ...        ...     ...          ...      ...        ...
# 1478  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1479  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1480  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1481  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1482  NaN     NaN        NaN     NaN          NaN      NaN        NaN
#
#              oem            model  modelYear  ...  Ground Clearance Unladen  \
# ...

# %% [markdown]
# Delhi Cars

# %%
delhi_cars.drop('car_links',axis=1,inplace=True)

# %%
#parase entire table
delhi_cars=parse_json_column(delhi_cars,delhi_cars.columns)

# %%
new_car_details_dl=pd.json_normalize(delhi_cars['new_car_detail'])
new_car_details_dl
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  centralVariantId  \
# 0               Kia         Kia Seltos       2022              7121
# ...

# %%
new_car_overview_dl=pd.json_normalize(delhi_cars['new_car_overview'])
new_car_overview_dl
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Jan 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2017',...
# ...            ...                                                ...
# 1480  Car overview  [{'key': 'Registration Year', 'value': '2019',...
# 1481  Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 1482  Car overview  [{'key': 'Registration Year', 'value': '2011',...
# 1483  Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
# 1484  Car overview  [{'key': 'Insurance Validity', 'value': 'Third...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_dl.drop('bottomData',axis=1,inplace=True)

# %%
new_car_overview_dl_top=new_car_overview_dl['top'].apply(list_to_dict)
new_car_overview_dl_top=pd.json_normalize(new_car_overview_dl_top)
new_car_overview_dl_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Diesel  5 Seats  10,000 Kms
# 1             May 2016               Zero Dep    Petrol  5 Seats  57,437 Kms
# 2             Dec 2020          Comprehensive    Petrol  5 Seats   8,000 Kms
# 3             Jan 2019          Comprehensive    Petrol  5 Seats  28,151 Kms
# 4                 2017  Third Party insurance    Petrol  5 Seats  60,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1480              2019  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1481              2021  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1482              2011  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1483          Oct 2019  Third Party insurance    Diesel  5 Seats  38,000 Kms
# 1484               NaN  Third Party insurance    Diesel  6 Seats   7,000 Kms
#
# ...

# %%
new_car_specs_dl=pd.json_normalize(delhi_cars['new_car_specs'])
new_car_specs_dl.drop('commonIcon',axis=1,inplace=True)
new_car_specs_dl
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '12.74 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# ...              ...                                                ...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1481  Specifications  [{'key': 'Mileage', 'value': '18.4 kmpl'}, {'k...
# 1482  Specifications  [{'key': 'Mileage', 'value': '17.01 kmpl'}, {'...
# 1483  Specifications  [{'key': 'Mileage', 'value': '20.5 kmpl'}, {'k...
# 1484  Specifications  [{'key': 'Mileage', 'value': '12.04 kmpl'}, {'...
#
#                                                    data
# ...

# %%
new_car_specs_dl_top=new_car_specs_dl['top'].apply(list_to_dict)
new_car_specs_dl_top=pd.json_normalize(new_car_specs_dl_top)
new_car_specs_dl_top
# Out:
#          Mileage   Engine  Max Power    Torque Wheel Size Seats
# 0        18 kmpl  1493 CC  113.43bhp     250Nm         17     5
# 1     15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN     5
# 2     12.74 kmpl  1991 CC     197bhp     320nm         19     5
# 3     22.38 kmpl  1197 CC   88.50bhp     113Nm        NaN     5
# 4     15.29 kmpl  1591 CC   121.3bhp     151Nm        NaN     5
# ...          ...      ...        ...       ...        ...   ...
# 1480     18 kmpl  1497 CC   117.6bhp     145Nm         15     5
# 1481   18.4 kmpl  1197 CC   81.86bhp     115Nm        NaN     5
# 1482  17.01 kmpl  1591 CC   121.3bhp   154.9Nm         16     5
# 1483   20.5 kmpl  1582 CC   126.2bhp  259.87NM         17     5
# 1484  12.04 kmpl  1996 CC  212.55bhp   478.5Nm         19     6
#
# [1485 rows x 6 columns]

# %%
new_car_specs_dl_data=pd.json_normalize(new_car_specs_dl['data'])
new_car_specs_dl_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1480  {'heading': 'Engine and Transmission', 'subHea...
# 1481  {'heading': 'Engine and Transmission', 'subHea...
# 1482  {'heading': 'Engine and Transmission', 'subHea...
# 1483  {'heading': 'Engine and Transmission', 'subHea...
# 1484  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_dl_data_0=pd.json_normalize(new_car_specs_dl_data[0])
new_car_specs_dl_data_0=new_car_specs_dl_data_0['list'].apply(list_to_dict)
new_car_specs_dl_data_0=pd.json_normalize(new_car_specs_dl_data_0)
new_car_specs_dl_data_0
# Out:
#        Color             Engine Type Displacement            Max Power  \
# 0       Gray          1.5 L CRDi VGT         1493    113.43bhp@4000rpm
# 1      White      VTVT Petrol Engine         1591     121.3bhp@6400rpm
# 2       Grey     M 264 petrol engine         1991  197bhp@5500-6100rpm
# 3     Silver       K Series Dual jet         1197     88.50bhp@6000rpm
# 4      White      VTVT Petrol Engine         1591     121.3bhp@6400rpm
# ...      ...                     ...          ...                  ...
# 1480  Others           i VTEC Engine         1497     117.6bhp@6600rpm
# 1481  Others        SMARTSTREAM G1.2         1197     81.86bhp@6000rpm
# 1482  Others      VTVT Petrol Engine         1591     121.3bhp@6300rpm
# 1483  Silver      U2 CRDI VGT Engine         1582     126.2bhp@4000rpm
# 1484    Grey  DIESEL 2.0L TWIN TURBO         1996    212.55bhp@4000rpm
#
#                  Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
new_car_specs_dl_data_1=pd.json_normalize(new_car_specs_dl_data[1])
new_car_specs_dl_data_1=new_car_specs_dl_data_1['list'].apply(list_to_dict)
new_car_specs_dl_data_1=pd.json_normalize(new_car_specs_dl_data_1)
new_car_specs_dl_data_1
# Out:
#       Length   Width  Height Wheel Base Kerb Weight Gross Weight Front Tread  \
# 0     4315mm  1800mm  1645mm     2610mm        1540          NaN         NaN
# 1     4270mm  1780mm  1630mm     2590mm       1,310          NaN         NaN
# 2     4658mm  1890mm  1644mm     2873mm        1585       2360kg         NaN
# 3     3845mm    1735    1530       2450     875-905         1335        1530
# 4     4270mm  1780mm  1630mm     2590mm       1,300          NaN         NaN
# ...      ...     ...     ...        ...         ...          ...         ...
# 1480  4440mm  1695mm  1495mm     2600mm      1080kg       1455kg      1490mm
# 1481  3995mm    1790    1642       2500        1192          NaN         NaN
# 1482  4375mm  1700mm  1475mm     2570mm        1260          NaN         NaN
# 1483  4270mm  1780mm  1665mm     2590mm        1340          NaN         NaN
# 1484  4985mm  1926mm  1867mm     2950mm        2600          NaN         NaN
#
# ...

# %%
new_car_specs_dl_data_2=pd.json_normalize(new_car_specs_dl_data[2])
new_car_specs_dl_data_2=new_car_specs_dl_data_2['list'].apply(list_to_dict)
new_car_specs_dl_data_2=pd.json_normalize(new_car_specs_dl_data_2)
new_car_specs_dl_data_2
# Out:
#             Gear Box Drive Type Seating Capacity Steering Type  \
# 0            6-Speed        FWD                5      Electric
# 1            6 Speed        FWD                5         Power
# 2     9 speed Tronic        AWD                5         Power
# 3            5-Speed        NaN                5      Electric
# 4            6 Speed        FWD                5         Power
# ...              ...        ...              ...           ...
# 1480             CVT        FWD                5         Power
# 1481         5-Speed        FWD                5      Electric
# 1482         5 Speed        FWD                5         Power
# 1483         6 Speed        FWD                5         Power
# 1484         8 Speed        4x4                6      Electric
#
#      Front Brake Type Rear Brake Type         Tyre Type Alloy Wheel Size  \
# 0                Disc            Disc  Tubeless, Radial               17
# ...

# %%
delhi_cars=pd.concat([new_car_details_dl,new_car_overview_dl_top,new_car_specs_dl_top,new_car_specs_dl_data_0,new_car_specs_dl_data_1,new_car_specs_dl_data_2])

# %%
delhi_cars['City']='Delhi'

# %%
delhi_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\delhi_cars.csv",index=False)
delhi_cars
# Out:
#        it      ft         bt      km transmission  ownerNo      owner  \
# 0     0.0  Diesel        SUV  10,000    Automatic      1.0  1st Owner
# 1     0.0  Petrol        SUV  57,437       Manual      2.0  2nd Owner
# 2     0.0  Petrol        SUV   8,000    Automatic      1.0  1st Owner
# 3     0.0  Petrol  Hatchback  28,151       Manual      2.0  2nd Owner
# 4     0.0  Petrol        SUV  60,000       Manual      1.0  1st Owner
# ...   ...     ...        ...     ...          ...      ...        ...
# 1480  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1481  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1482  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1483  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1484  NaN     NaN        NaN     NaN          NaN      NaN        NaN
#
#                 oem              model  modelYear  ...  Turning Radius  \
# ...

# %% [markdown]
# Chennai Cars

# %%
chennai_cars.drop('car_links',axis=1,inplace=True)

# %%
#parase entire table
chennai_cars=parse_json_column(chennai_cars,chennai_cars.columns)

# %%
new_car_details_CSK=pd.json_normalize(chennai_cars['new_car_detail'])
new_car_details_CSK
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
new_car_overview_CSK=pd.json_normalize(chennai_cars['new_car_overview'])
new_car_overview_CSK
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 1414  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 1415  Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 1416  Car overview  [{'key': 'Registration Year', 'value': 'Aug 20...
# 1417  Car overview  [{'key': 'Registration Year', 'value': 'Aug 20...
# 1418  Car overview  [{'key': 'Registration Year', 'value': 'Oct 20...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_CSK.drop('bottomData',axis=1,inplace=True)

# %%
new_car_overview_CSK_top=new_car_overview_CSK['top'].apply(list_to_dict)
new_car_overview_CSK_top=pd.json_normalize(new_car_overview_CSK_top)
new_car_overview_CSK_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1             Feb 2015          Comprehensive    Petrol  7 Seats  20,687 Kms
# 2                 2021  Third Party insurance    Petrol  5 Seats  30,000 Kms
# 3             May 2015          Comprehensive    Petrol  5 Seats  59,247 Kms
# 4                 2015  Third Party insurance    Petrol  5 Seats  50,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1414          Jun 2018  Third Party insurance    Petrol  5 Seats  42,891 Kms
# 1415          Feb 2019  Third Party insurance    Diesel  5 Seats  59,100 Kms
# 1416          Aug 2018          Not Available    Petrol  5 Seats  55,913 Kms
# 1417          Aug 2017          Comprehensive    Diesel  5 Seats  65,000 Kms
# 1418          Oct 2019          Comprehensive    Diesel  5 Seats  60,000 Kms
#
# ...

# %%
new_car_specs_CSK=pd.json_normalize(chennai_cars['new_car_specs'])
new_car_specs_CSK.drop('commonIcon',axis=1,inplace=True)
new_car_specs_CSK
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Engine', 'value': '998 CC'}, {'key':...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.37 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '20 kmpl'}, {'key...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.81 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '18.7 kmpl'}, {'k...
# ...              ...                                                ...
# 1414  Specifications  [{'key': 'Mileage', 'value': '22 kmpl'}, {'key...
# 1415  Specifications  [{'key': 'Mileage', 'value': '19.87 kmpl'}, {'...
# 1416  Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 1417  Specifications  [{'key': 'Mileage', 'value': '16.65 kmpl'}, {'...
# 1418  Specifications  [{'key': 'Mileage', 'value': '21.76 kmpl'}, {'...
#
#                                                    data
# ...

# %%
new_car_specs_CSK_top=new_car_specs_CSK['top'].apply(list_to_dict)
new_car_specs_CSK_top=pd.json_normalize(new_car_specs_CSK_top)
new_car_specs_CSK_top
# Out:
#        Engine  Max Power   Torque Wheel Size Seats     Mileage
# 0      998 CC  118.36bhp    172nm         16     5         NaN
# 1     1196 CC      73bhp    101Nm        NaN     7  15.37 kmpl
# 2      999 CC   98.63bhp    160Nm         16     5     20 kmpl
# 3     1086 CC   68.05bhp  99.04Nm        NaN     5  19.81 kmpl
# 4     1199 CC    88.7bhp    110Nm         15     5   18.7 kmpl
# ...       ...        ...      ...        ...   ...         ...
# 1414  1197 CC   81.80bhp    113Nm        NaN     5     22 kmpl
# 1415  1461 CC    83.8bhp    200Nm         16     5  19.87 kmpl
# 1416  1198 CC   108.5bhp    170Nm         16     5     17 kmpl
# 1417  1968 CC     141bhp    340Nm         18     5  16.65 kmpl
# 1418  1995 CC     188bhp    400Nm         18     5  21.76 kmpl
#
# [1419 rows x 6 columns]

# %%
new_car_specs_CSK_data=pd.json_normalize(new_car_specs_CSK['data'])
new_car_specs_CSK_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1414  {'heading': 'Engine and Transmission', 'subHea...
# 1415  {'heading': 'Engine and Transmission', 'subHea...
# 1416  {'heading': 'Engine and Transmission', 'subHea...
# 1417  {'heading': 'Engine and Transmission', 'subHea...
# 1418  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_CSK_data_0=pd.json_normalize(new_car_specs_CSK_data[0])
new_car_specs_CSK_data_0=new_car_specs_CSK_data_0['list'].apply(list_to_dict)
new_car_specs_CSK_data_0=pd.json_normalize(new_car_specs_CSK_data_0)
new_car_specs_CSK_data_0
# Out:
#        Color                               Engine Type Displacement  \
# 0      Black                  Smartstream G1.0 T - GDi          998
# 1       Grey                            In-Line Engine         1196
# 2     Others                     HRA0 1.0 TURBO PETROL          999
# 3     Silver                              IRDE2 Engine         1086
# 4     Others                      i-VTEC Petrol Engine         1199
# ...      ...                                       ...          ...
# 1414    Blue                               VTVT Engine         1197
# 1415  Orange                     dCi THP Diesel Engine         1461
# 1416   White         Revotron 1.2L Turbocharged engine         1198
# 1417    Grey              Common Rail Direct Injection         1968
# 1418   White  TwinPower Turbo 4-Cylinder Diesel Engine         1995
#
#               Max Power          Max Torque  No of Cylinder  \
# 0     118.36bhp@6000rpm  172nm@1500-4000rpm             3.0
# ...

# %%
new_car_specs_CSK_data_1=pd.json_normalize(new_car_specs_CSK_data[1])
new_car_specs_CSK_data_1=new_car_specs_CSK_data_1['list'].apply(list_to_dict)
new_car_specs_CSK_data_1=pd.json_normalize(new_car_specs_CSK_data_1)
new_car_specs_CSK_data_1
# Out:
#       Length   Width  Height Wheel Base Kerb Weight Front Tread Rear Tread  \
# 0     3995mm    1790    1642       2500        1465         NaN        NaN
# 1     3675mm  1475mm  1800mm     2350mm       943kg      1280mm     1290mm
# 2     3994mm    1758    1572       2500        1014         NaN        NaN
# 3     3585mm  1595mm  1550mm     2380mm       860kg      1400mm     1385mm
# 4     3955mm  1694mm  1544mm     2530mm      1042kg         NaN        NaN
# ...      ...     ...     ...        ...         ...         ...        ...
# 1414  3840mm  1735mm  1530mm     2450mm       865Kg      1530mm     1530mm
# 1415  4315mm  1822mm  1695mm     2673mm        1210      1560mm     1567mm
# 1416  3994mm  1811mm  1607mm     2498mm      1252Kg     1540 mm    1530 mm
# 1417  4486mm  1839mm  1672mm     2677mm      1720kg      1578mm     1568mm
# 1418  4824mm  1828mm  1508mm    2920 mm        1720     1541 mm    1581 mm
#
# ...

# %%
new_car_specs_CSK_data_2=pd.json_normalize(new_car_specs_CSK_data[2])
new_car_specs_CSK_data_2=new_car_specs_CSK_data_2['list'].apply(list_to_dict)
new_car_specs_CSK_data_2=pd.json_normalize(new_car_specs_CSK_data_2)
new_car_specs_CSK_data_2
# Out:
#          Gear Box Drive Type Seating Capacity Steering Type Front Brake Type  \
# 0     7-Speed DCT        FWD                5      Electric             Disc
# 1         5 Speed        RWD                7        Manual  Ventilated Disc
# 2         5 Speed        NaN                5    Electronic             Disc
# 3         5 Speed        FWD                5         Power  Ventilated Disc
# 4         5 Speed        FWD                5         Power             Disc
# ...           ...        ...              ...           ...              ...
# 1414            5        NaN                5         Power             Disc
# 1415      5 speed        FWD                5         Power             Disc
# 1416      6 Speed        FWD                5         Power             Disc
# 1417      7 Speed        AWD                5      Electric             Disc
# 1418      8 Speed        RWD                5         Power             Disc
#
# ...

# %%
chennai_cars=pd.concat([new_car_details_CSK,new_car_overview_CSK_top,new_car_specs_CSK_top,new_car_specs_CSK_data_0,new_car_specs_CSK_data_1,new_car_specs_CSK_data_2])

# %%
chennai_cars['City']='Chennai'

# %%
chennai_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\chennai_cars.csv",index=True)
chennai_cars
# Out:
#        it      ft         bt      km transmission  ownerNo      owner  \
# 0     0.0  Petrol        SUV  20,000    Automatic      1.0  1st Owner
# 1     0.0  Petrol   Minivans  20,687       Manual      1.0  1st Owner
# 2     0.0  Petrol        SUV  30,000       Manual      1.0  1st Owner
# 3     0.0  Petrol  Hatchback  59,247       Manual      1.0  1st Owner
# 4     0.0  Petrol  Hatchback  50,000       Manual      1.0  1st Owner
# ...   ...     ...        ...     ...          ...      ...        ...
# 1414  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1415  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1416  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1417  NaN     NaN        NaN     NaN          NaN      NaN        NaN
# 1418  NaN     NaN        NaN     NaN          NaN      NaN        NaN
#
#           oem           model  modelYear  ...  No Door Numbers Gear Box  \
# ...

# %% [markdown]
# Bangalore_cars

# %%
bangalore_cars.drop('car_links',axis=1,inplace=True)

# %%
#parase entire table
bangalore_cars=parse_json_column(bangalore_cars,bangalore_cars.columns)

# %%
new_car_details_bl=pd.json_normalize(bangalore_cars['new_car_detail'])
new_car_details_bl
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# ...

# %%
new_car_overview_bl=pd.json_normalize(bangalore_cars['new_car_overview'])
new_car_overview_bl
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 1476  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 1477  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 1478  Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 1479  Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 1480  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
#
#      bottomData
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...
# ...

# %%
new_car_overview_bl.drop('bottomData',axis=1,inplace=True)

# %%
new_car_overview_bl_top=new_car_overview_bl['top'].apply(list_to_dict)
new_car_overview_bl_top=pd.json_normalize(new_car_overview_bl_top)
new_car_overview_bl_top
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Petrol  5 Seats
# 1             Feb 2018          Comprehensive    Petrol  5 Seats
# 2            Sept 2018          Comprehensive    Petrol  5 Seats
# 3             Dec 2014          Comprehensive    Petrol  5 Seats
# 4                 2015  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1476          May 2012          Comprehensive    Diesel  7 Seats
# 1477          Jun 2008  Third Party insurance    Petrol  5 Seats
# 1478         Sept 2014          Comprehensive    Petrol  5 Seats
# 1479          Dec 2018          Comprehensive    Diesel  5 Seats
# 1480          May 2017          Comprehensive    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  KA51   Third Owner              998 cc       Manual
# ...

# %%
new_car_specs_bl=pd.json_normalize(bangalore_cars['new_car_specs'])
new_car_specs_bl.drop('commonIcon',axis=1,inplace=True)
new_car_specs_bl
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 1     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.84 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.1 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '23.65 kmpl'}, {'...
# ...              ...                                                ...
# 1476  Specifications  [{'key': 'Mileage', 'value': '12.55 kmpl'}, {'...
# 1477  Specifications  [{'key': 'Mileage', 'value': '15 kmpl'}, {'key...
# 1478  Specifications  [{'key': 'Mileage', 'value': '19.4 kmpl'}, {'k...
# 1479  Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
#
#                                                    data
# ...

# %%
new_car_specs_bl_top=new_car_specs_bl['top'].apply(list_to_dict)
new_car_specs_bl_top=pd.json_normalize(new_car_specs_bl_top)
new_car_specs_bl_top
# Out:
#          Mileage   Engine  Max Power    Torque Seats Wheel Size
# 0      23.1 kmpl   998 CC   67.04bhp      90Nm     5        NaN
# 1        17 kmpl  1497 CC  121.31bhp     150Nm     5         16
# 2     23.84 kmpl  1199 CC      84bhp     114Nm     5         14
# 3      19.1 kmpl  1197 CC   81.86bhp  113.75Nm     5         14
# 4     23.65 kmpl  1248 CC    88.5bhp     200Nm     5         16
# ...          ...      ...        ...       ...   ...        ...
# 1476  12.55 kmpl  2982 CC   168.5bhp     343Nm     7         17
# 1477     15 kmpl  1586 CC     104.68       145     5         16
# 1478   19.4 kmpl  1198 CC    86.8bhp     109Nm     5        NaN
# 1479  22.54 kmpl  1396 CC   88.73bhp   219.7Nm     5         16
# 1480   18.9 kmpl  1197 CC      82bhp     114Nm     5         14
#
# [1481 rows x 6 columns]

# %%
new_car_specs_bl_data=pd.json_normalize(new_car_specs_bl['data'])
new_car_specs_bl_data
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 1476  {'heading': 'Engine and Transmission', 'subHea...
# 1477  {'heading': 'Engine and Transmission', 'subHea...
# 1478  {'heading': 'Engine and Transmission', 'subHea...
# 1479  {'heading': 'Engine and Transmission', 'subHea...
# 1480  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
new_car_specs_bl_data_0=pd.json_normalize(new_car_specs_bl_data[0])
new_car_specs_bl_data_0=new_car_specs_bl_data_0['list'].apply(list_to_dict)
new_car_specs_bl_data_0=pd.json_normalize(new_car_specs_bl_data_0)
new_car_specs_bl_data_0
# Out:
#        Color               Engine Type Displacement              Max Power  \
# 0      White               K10B Engine          998       67.04bhp@6000rpm
# 1      White      Ti-VCT Petrol Engine         1497      121.31bhp@6500rpm
# 2        Red           Revotron Engine         1199          84bhp@6000rpm
# 3     Others  Kappa VTVT Petrol Engine         1197       81.86bhp@6000rpm
# 4       Gray    DDiS 200 Diesel Engine         1248        88.5bhp@4000rpm
# ...      ...                       ...          ...                    ...
# 1476    Blue        D-4D Diesel Engine         2982       168.5bhp@3600rpm
# 1477     Red            In-Line Engine         1586  104.68@5,600 (PS@rpm)
# 1478   White             i-VTEC Engine         1198        86.8bhp@6000rpm
# 1479     Red     U2 CRDI Diesel Engine         1396       88.73bhp@4000rpm
# 1480   White  Kappa VTVT Petrol Engine         1197          82bhp@6000rpm
#
#                 Max Torque  No of Cylinder  Values per Cylinder  \
# ...

# %%
new_car_specs_bl_data_1=pd.json_normalize(new_car_specs_bl_data[1])
new_car_specs_bl_data_1=new_car_specs_bl_data_1['list'].apply(list_to_dict)
new_car_specs_bl_data_1=pd.json_normalize(new_car_specs_bl_data_1)
new_car_specs_bl_data_1
# Out:
#       Length   Width  Height Wheel Base Front Tread Rear Tread Kerb Weight  \
# 0     3715mm  1635mm  1565mm     2425mm      1420mm     1410mm       835kg
# 1     3998mm  1765mm  1647mm     2519mm         NaN        NaN      1242Kg
# 2     3746mm  1647mm  1535mm     2400mm      1400mm     1420mm      1012kg
# 3     3995mm  1660mm  1520mm     2425mm      1479mm     1493mm        1180
# 4     4300mm  1785mm  1595mm     2600mm         NaN        NaN      1230Kg
# ...      ...     ...     ...        ...         ...        ...         ...
# 1476  4705mm  1840mm  1850mm     2750mm      1540mm     1540mm      1970kg
# 1477  4490mm  1735mm  1570mm     2500mm      1500mm     1495mm      1200kg
# 1478  3610mm  1680mm  1500mm     2345mm      1480mm     1465mm       925kg
# 1479  3985mm  1734mm  1505mm     2570mm      1505mm     1503mm      1515kg
# 1480  3765mm  1660mm  1520mm     2425mm      1479mm     1493mm       935kg
#
# ...

# %%
new_car_specs_bl_data_2=pd.json_normalize(new_car_specs_bl_data[2])
new_car_specs_bl_data_2=new_car_specs_bl_data_2['list'].apply(list_to_dict)
new_car_specs_bl_data_2=pd.json_normalize(new_car_specs_bl_data_2)
new_car_specs_bl_data_2
# Out:
#       Gear Box Drive Type Seating Capacity Steering Type Turning Radius  \
# 0     5 Speed         FWD                5         Power     4.7 metres
# 1      5 Speed        FWD                5         Power     5.3 metres
# 2      5 Speed        FWD                5         Power     4.9 meters
# 3     5 Speed        FWD                 5         Power     4.7 metres
# 4      5 Speed        FWD                5         Power     5.2 meters
# ...        ...        ...              ...           ...            ...
# 1476   5 Speed        4WD                7         Power     5.9 metres
# 1477   5 Speed        NaN                5         Power          5.3 m
# 1478   5 Speed        FWD                5         Power     4.5 metres
# 1479   6 Speed        FWD                5         Power     5.2 metres
# 1480   4 Speed        FWD                5         Power     4.8 metres
#
#      Front Brake Type Rear Brake Type Top Speed   Acceleration  \
# ...

# %%
bangalore_cars=pd.concat([new_car_details_bl,new_car_overview_bl_top,new_car_specs_bl_top,new_car_specs_bl_data_0,new_car_specs_bl_data_1,new_car_specs_bl_data_2])

# %%
bangalore_cars['City']='Bangalore'

# %%
bangalore_cars.to_csv(r"C:\Users\prave\OneDrive\Documents\GUVI\car dheko\bangalore_cars.csv",index=False)
bangalore_cars
# Out:
#        it      ft         bt        km transmission  ownerNo      owner  \
# 0     0.0  Petrol  Hatchback  1,20,000       Manual      3.0  3rd Owner
# 1     0.0  Petrol        SUV    32,706       Manual      2.0  2nd Owner
# 2     0.0  Petrol  Hatchback    11,949       Manual      1.0  1st Owner
# 3     0.0  Petrol      Sedan    17,794       Manual      1.0  1st Owner
# 4     0.0  Diesel        SUV    60,000       Manual      1.0  1st Owner
# ...   ...     ...        ...       ...          ...      ...        ...
# 1476  NaN     NaN        NaN       NaN          NaN      NaN        NaN
# 1477  NaN     NaN        NaN       NaN          NaN      NaN        NaN
# 1478  NaN     NaN        NaN       NaN          NaN      NaN        NaN
# 1479  NaN     NaN        NaN       NaN          NaN      NaN        NaN
# 1480  NaN     NaN        NaN       NaN          NaN      NaN        NaN
#
#           oem               model  modelYear  ...  Ground Clearance Unladen  \
# ...
